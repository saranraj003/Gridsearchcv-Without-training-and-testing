# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
'C':[10,1000]}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 1000],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 1000, 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.174988      0.022963         0.093744    1.302385e-06      10
# 1       0.143740      0.015308         0.031247    1.457282e-06      10
# 2       0.187487      0.009881         0.034372    6.250191e-03      10
# 3       0.149990      0.007654         0.021873    7.654247e-03      10
# 4       0.168738      0.006250         0.090619    6.249714e-03    1000
# 5       0.190611      0.011692         0.031249    7.478899e-07    1000
# 6       0.215610      0.024999         0.040622    7.654889e-03    1000
# 7       0.953063      0.155606         0.012500    6.249953e-03    1000
#
#   param_kernel                            params  split0_test_score  \
# 0          rbf        {'C': 10, 'kernel': 'rbf'}          -0.110409
# 1         poly       {'C': 10, 'kernel': 'poly'}          -0.125153
# 2      sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 3       linear     {'C': 10, 'kernel': 'linear'}          -0.018943
# 4          rbf      {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 5         poly     {'C': 1000, 'kernel': 'poly'}          -0.080527
# 6      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
# 7       linear   {'C': 1000, 'kernel': 'linear'}           0.736398
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.097459          -0.074488          -0.099597          -0.124428
# 1          -0.081505          -0.111907          -0.131602          -0.179328
# 2          -0.119312          -0.085214          -0.108210          -0.108716
# 3           0.029886           0.022167           0.003112          -0.066653
# 4          -0.098267          -0.123724          -0.137137          -0.206405
# 5          -0.028469          -0.073376          -0.086611          -0.134493
# 6          -2.686121          -2.194563          -2.210858          -1.942521
# 7           0.675162           0.680002           0.699377           0.677952
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.101276        0.016459                4
# 1        -0.125899        0.031794                6
# 2        -0.107639        0.012029                5
# 3        -0.006086        0.034672                2
# 4        -0.144193        0.036262                7
# 5        -0.080695        0.033795                3
# 6        -2.215441        0.255409                8
# 7         0.693778        0.022955                1

# %%
import pickle
filename="finalized_model_SVMR_Gridsearchcv.sav"
pickle.dump(grid,open(filename,'wb'))
